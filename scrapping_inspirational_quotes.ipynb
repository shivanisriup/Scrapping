# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.geeksforgeeks.org/data-structures/"
r = requests.get(URL) 
print(r.content)
# Out:
# b'<!DOCTYPE html>\r\n<!--[if IE 7]>\r\n<html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n<html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="en-US" prefix="og: http://ogp.me/ns#" >\r\n\r\n<!--<![endif]-->\r\n<head>\r\n<meta charset="UTF-8" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"> \r\n\r\n<link rel="shortcut icon" href="https://www.geeksforgeeks.org/favicon.ico" type="image/x-icon" />\r\n<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\r\n<meta name="theme-color" content="#0f9d58" />\r\n\r\n<meta property="og:image" content="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png">\r\n<meta property="og:image:type" content="image/png">\r\n<meta property="og:image:width" content="200">\r\n<meta property="og:image:height" content="200">\r\n<script src="http
# ...

# %%
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <title>
#    Inspirational Quotes - Motivational Quotes - Leadership Quotes | PassItOn.com
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1" name="viewport"/>
#   <meta content="The Foundation for a Better Life | Pass It On.com" name="description"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#c8102e" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
# ...

# %%
quotes=[]  # a list to store quotes 
  
table = soup.find('div', attrs = {'id':'all_quotes'}) 
#print(table)
  
for row in table.findAll('div', attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    print(row)
    quote = {} 
    quote['theme'] = row.h5.text 
    quote['url'] = row.a['href'] 
    quote['img'] = row.img['src'] 
    before_keyword, keyword, after_keyword = row.img['alt'].partition('#')
    quote['author'] = after_keyword
    quote['lines'] = before_keyword
    quotes.append(quote)
# Out:
# <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#
#         <a href="/inspirational-quotes/8056-when-i-was-a-boy-and-i-would-see-scary-things"><img alt="When I was a boy and I would see scary things in the news, my mother would say to me, ‘Look for the helpers. You will always find people who are helping.’ #&lt;Author:0x00007fbedc08ee20&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8056/medium/20200406_monday_quote.jpg?1585942742" width="310"/></a>
#         <h5 class="value_on_red"><a href="/inspirational-quotes/8056-when-i-was-a-boy-and-i-would-see-scary-things">HELPING OTHERS</a></h5>
#
# </div>
# <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#
# ...

# %%
quotes
# Out:
# [{'theme': 'HELPING OTHERS',
#   'url': '/inspirational-quotes/8056-when-i-was-a-boy-and-i-would-see-scary-things',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8056/medium/20200406_monday_quote.jpg?1585942742',
#   'author': '<Author:0x00007fbedc08ee20>',
#   'lines': 'When I was a boy and I would see scary things in the news, my mother would say to me, ‘Look for the helpers. You will always find people who are helping.’ '},
#  {'theme': 'OPTIMISM',
#   'url': '/inspirational-quotes/6151-we-have-enough-people-who-tell-it-like-it',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/6151/medium/20200403_friday_quote.jpg?1585244301',
#   'author': '<Author:0x00007fbedbf3cbd0>',
#   'lines': 'We have enough people who tell it like it is—now we could use a few who tell it like it can be.  '},
#  {'theme': 'OPTIMISM',
#   'url': '/inspirational-quotes/8055-an-optimist-understands-that-life-can-be-a',
# ...

# %%
import csv
filename = 'inspirational_quotes.csv'
with open(filename, 'w') as f: 
    w = csv.DictWriter(f,['theme','url','img','lines','author']) 
    w.writeheader() 
    for quote in quotes: 
        w.writerow(quote)

# %%
import random
#randint game winner 
namelist = []
namelist.append(input("Please enter name 1:"))  #Stored in namelist[0]
namelist.append(input('Please enter name 2:'))  #Stored in namelist[1]
namelist.append(input('Please enter name 3:'))  #Stored in namelist[2]
namelist.append(input('Please enter name 4:'))  #Stored in namelist[3]
namelist.append(input('Please enter name 5:'))  #Stored in namelist[4]

nameindex = random.randint(0, 5)
print('Well done {}. You are the winner!'.format(namelist[nameindex]))
# Out:
# Please enter name 1:shivani
# Please enter name 2:shripali
# Please enter name 3:tushar
# Please enter name 4:shivangi
# Please enter name 5:kumkum
# Well done kumkum. You are the winner!

# %%
import pandas as pd

# %%
data=pd.read_csv('inspirational_quotes.csv')

# %%
data
# Out:
#                 theme                                                url  \
# 0      HELPING OTHERS  /inspirational-quotes/8056-when-i-was-a-boy-an...
# 1            OPTIMISM  /inspirational-quotes/6151-we-have-enough-peop...
# 2            OPTIMISM  /inspirational-quotes/8055-an-optimist-underst...
# 3            OPTIMISM  /inspirational-quotes/6905-if-we-had-no-winter...
# 4            OPTIMISM  /inspirational-quotes/3623-the-greatest-discov...
# 5            OPTIMISM  /inspirational-quotes/7377-love-is-better-than...
# 6              WISDOM  /inspirational-quotes/8054-knowledge-comes-fro...
# 7              WISDOM  /inspirational-quotes/8053-it-is-said-that-wis...
# 8              WISDOM  /inspirational-quotes/4069-we-are-made-wise-no...
# 9              WISDOM  /inspirational-quotes/8052-never-mistake-knowl...
# 10             WISDOM  /inspirational-quotes/6246-the-invariable-mark...
# 11         RESILIENCE  /inspirational-quotes/6554-life-has-many-ways-...
# ...

# %%
data.shape
# Out:
# (32, 5)

# %%
data.dtypes
# Out:
# theme     object
# url       object
# img       object
# lines     object
# author    object
# dtype: object

# %%
data.head()
# Out:
#             theme                                                url  \
# 0  HELPING OTHERS  /inspirational-quotes/8056-when-i-was-a-boy-an...
# 1        OPTIMISM  /inspirational-quotes/6151-we-have-enough-peop...
# 2        OPTIMISM  /inspirational-quotes/8055-an-optimist-underst...
# 3        OPTIMISM  /inspirational-quotes/6905-if-we-had-no-winter...
# 4        OPTIMISM  /inspirational-quotes/3623-the-greatest-discov...
#
#                                                  img  \
# 0  https://assets.passiton.com/quotes/quote_artwo...
# 1  https://assets.passiton.com/quotes/quote_artwo...
# 2  https://assets.passiton.com/quotes/quote_artwo...
# 3  https://assets.passiton.com/quotes/quote_artwo...
# 4  https://assets.passiton.com/quotes/quote_artwo...
#
#                                                lines  \
# 0  When I was a boy and I would see scary things ...
# 1  We have enough people who tell it like it is—n...
# 2  An optimist understands that life can be a bum...
# ...

# %%
data.tail()
# Out:
#        theme                                                url  \
# 27   PASSION  /inspirational-quotes/8041-passion-is-the-gene...
# 28   PASSION  /inspirational-quotes/8040-chase-down-your-pas...
# 29   PASSION  /inspirational-quotes/8039-if-you-feel-like-th...
# 30   PASSION  /inspirational-quotes/8038-only-passions-great...
# 31  OPTIMISM  /inspirational-quotes/6732-become-a-possibilit...
#
#                                                   img  \
# 27  https://assets.passiton.com/quotes/quote_artwo...
# 28  https://assets.passiton.com/quotes/quote_artwo...
# 29  https://assets.passiton.com/quotes/quote_artwo...
# 30  https://assets.passiton.com/quotes/quote_artwo...
# 31  https://assets.passiton.com/quotes/quote_artwo...
#
#                                                 lines  \
# 27                 Passion is the genesis of genius.
# 28  Chase down your passion like it’s the last bus...
# 29  If you feel like there’s something out there t...
# ...

# %%
data.isnull().sum()
# Out:
# theme     0
# url       0
# img       0
# lines     0
# author    0
# dtype: int64

# %%
data['theme'].unique()
# Out:
# array(['HELPING OTHERS', 'OPTIMISM', 'WISDOM', 'RESILIENCE',
#        'TRUE BEAUTY', 'SPREAD YOUR WINGS', 'PASSION'], dtype=object)
